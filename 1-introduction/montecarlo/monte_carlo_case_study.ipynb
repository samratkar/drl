# %% [markdown]
# # Monte Carlo Gridworld Case Study
#
# This notebook runs first-visit on-policy Monte Carlo control on the shared 3x3 stochastic gridworld used in the DRL study material.

# %%
from monte_carlo_case_study import run_first_visit_mc_control
payload = run_first_visit_mc_control()
payload['algorithm'], payload['num_episodes']
# Out:
# ('first_visit_on_policy_monte_carlo_control', 7000)

# %%
payload['final']['state_scores']
# Out:
# [2.848558537483215,
#  4.97079880627272,
#  7.048402948807885,
#  4.914539481518372,
#  7.1275953269173105,
#  9.488430002917333,
#  7.063312489848013,
#  9.897222190685609,
#  0.0]

# %%
payload['final']['Q']
# Out:
# [[0.9120444122521231,
#   2.848558537483215,
#   2.0965297615691263,
#   1.380167634973619],
#  [2.716215966824542, 4.97079880627272, 4.2086891292984525, 1.8094284658323976],
#  [4.38557955724615, 4.571726283430349, 7.048402948807885, 3.181773443321768],
#  [1.0807958016961747, 3.750967250121637, 4.914539481518372, 1.951857607352288],
#  [3.172107199554875,
#   6.2124721035618995,
#   7.1275953269173105,
#   2.388366443360043],
#  [4.544719393720636, 7.2260749507196955, 9.488430002917333, 5.320329254104858],
#  [3.5700347032556947,
#   7.063312489848013,
#   4.066575822258958,
#   3.4259006784655073],
#  [5.471354424437307, 9.897222190685609, 6.911946841218067, 4.593762991439669],
#  [0.0, 0.0, 0.0, 0.0]]

# %%
from pathlib import Path
import json
output_path = Path('monte_carlo_policies.json')
output_path.write_text(json.dumps(payload, indent=2), encoding='utf-8')
output_path.resolve()
# Out:
# PosixPath('/Users/samrat.kar/git/drl/2-reinforce/montecarlo/monte_carlo_policies.json')
